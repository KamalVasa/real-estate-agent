# %% [markdown]
# 1.Whenever we will open a node.js project 1st we will notice is the package.json file

# %% [markdown]
# 1.Jabhi node.js koi proj open krta he to sabse pehle wo package.json dhundta he

# %% [markdown]
# ## {
#
# 1.It simply means that the file is written in json
#
# 2.json is a way of storing info

# %% [markdown]
# ## "private": true
#
# 1.It means this proj cannot be published accidently to public npm registry

# %% [markdown]
# ## "scripts": {
#
# 1.Suppose there is no package.json and now u open a terminal and type npm run dev,So node(i.e npm ) will think what is dev ?
#
# 2.Now suppose there is a package.json file and it has dev inside scripts and then u run npm run dev so npm will open package.json it looks inside scripts and it will search for the dev and once it gets then npm says ohh developer wants me to execute
#
# 3.Actually npm doesnt know how to run,it justs follows the instructions
#
# 4.Eg :
# a.Suppose i tell u go to my house and maps asks where is ur house and then u give the address and then maps follows the address

# %% [markdown]
# ## npm run dev
#
# 1.When we run this npm actually finds the package.json and it looks for the dev then it finds next dev and it runs next dev and then finaly it starts the nextjs server

# %% [markdown]
# ## "build": "next build"
#
# 1.This prepares the proj for production
#
# 2.Develeopment ke time pe to slower,easy to edit etc hota he
#
# 3.But during deployment we build optimized,compressed,faster etc

# %% [markdown]
# ## "start": "next start"
#
# 1.This runs the built app
#
# 2.During development -->npm run dev
#
# 3.During production -->npm run build -> npm run start

# %% [markdown]
# ## "lint": "next lint"
#
# 1.This checks ur code for msitakes
#
# 2.Not bugs but coding mistakes eg u forget a variable or etc

# %% [markdown]
# ## "dependencies"
#
# 1.Dependencies matlab apps installed on ur phone
#
# 2.our proj doesnt know how to create a webpage on its own so it depends on other apps/software

# %% [markdown]
# ## "typescript": "5.8.3"
#
# 1.This proj is written in typescript
#
# 2.
