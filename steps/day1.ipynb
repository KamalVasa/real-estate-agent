# %% [markdown]
# 1.1st simply read the files.ipynb inside the notes folder
#
# 2.Then read the package_json.ipynb from the notes folder
#
# 3.Then we will start with running the frontend part

# %% [markdown]
# ## Frontend part
#
# 1.Open terminal and type npm run dev
#
# 2.After running open your browser and then go to http://localhost:3000
#
# 3.Right now, what is actually running?
#
# Only this part:
#
# Browser
#      │
#      ▼
# Next.js Frontend ✅
#
# But your project actually looks like this:
#
#                  Browser
#                      │
#                      ▼
#       Next.js Frontend (Running ✅)
#                      │
#               REST API Calls
#                      │
#                      ▼
#       FastAPI Backend (Not Running ❌)
#                      │
#                      ▼
#           SQLite Database
#
# 4. Suppose ki customer can open the food app but the kitchen is closed if the cust clicks order food then nothing useful can happen kyuki koi khana banane he hi nhi
#
# 5.Now we will run the fastapi backend make sure we should be in backend directory or frontend directory for running them
