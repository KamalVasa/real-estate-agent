# %% [markdown]
# ## backend
# 1. 1st go to the backend folder and then check ls and then check ls app
#
# 2.This app folder is the heart of backend i.e
# __init__.py     __pycache__     config.py       database.py     main.py         marketing.py    models.py       schemas.py
#
# #### 1.main.py
# ->
# 1.This is probably where the fastapi server starts
# 2.Just like
# package.json-->nexr dev -->Frontend starts
# similarly main.py -->uvicorn --> backend starts
#
# #### 2.Database.py
# ->
# 1.This file connects to sqlite database and then creates a session and then initialize the database
# 2.Backend -->Database.py --> sqlite
#
# #### 3.models.py
# ->
# 1.This describes how actually database tables look like
#
# #### 4.schemas.py
# ->
# 1.Now somenone sends a json sends a json then who will check that the data is valid or not here comes the shemas.py
#
# #### 5.config.py
# ->
# 1.It contains api keys,env etc basically its a configuration center
#
# #### marketing,py
# ->
# 1.This contains gemini ai logic
#
# 2.Something like property -->Gemini -->Marketing description

# %% [markdown]
# ## 1.Now lets start the backend server
# 2.uvicorn app.main:app --reload it means go into the app folder and then open main.py
# 3.Inside main.py there is app as a fastapi obj i.e :app tells the uvicorn to run the app variable from main.py
# 4.Whenever we save the file uvicorn detects changes and the server restarts automatically
# 5.Actually --reload tells uvicorn to keep watching the proj
# 6.Same idea.
# | Frontend      | Backend                |
# | ------------- | ---------------------- |
# | `npm run dev` | `uvicorn ... --reload` |
# | Watches files | Watches files          |
# | Auto refresh  | Auto restart           |
# 7.Frontend
# http://localhost:3000
# 8.Backend
# http://127.0.0.1:8000
#
# 9.FastAPI is loading everything.
# Examples:
#
# Database connection
# Configuration
# Routes
# AI initialization

# %% [markdown]
# 1.In this project api will be used to connect it to the backend i.e
# 2.Browser -->Api --> Fastapi(backend) -->Database

# %% [markdown]
# ## 1.POST /properties/{property_id}/marketing
#
# This immediately caught my attention.
#
# Why?
# Because this is probably where your AI feature lives.
# Let's think about it.
#
# Suppose Property #7 is:
#
# 3 BHK
# Swimming pool
# Near station
# ₹85 Lakhs
#
# The frontend might send:
#
# Property ID = 7
#
# The backend then:
#
# Fetch Property
#         │
#         ▼
# Send details to Gemini/OpenAI
#         │
#         ▼
# Generate marketing description
#         │
#         ▼
# Return it to frontend
#
# I think this endpoint is going to be one of the most exciting parts of the project.

# %% [markdown]
# ## Architecture
#
# Let's understand the architecture now
# I want you to see the complete picture.
#
#                 Browser
#                     │
#                     ▼
#           Next.js Frontend
#                     │
#           User clicks button
#                     │
#                     ▼
#       HTTP Request (GET /properties)
#                     │
#                     ▼
#             FastAPI Backend
#                     │
#              Reads SQLite
#                     │
#                     ▼
#               Returns JSON
#                     │
#                     ▼
#           Frontend shows data
#
# Everything in your project follows this cycle.

# %% [markdown]
# ##
